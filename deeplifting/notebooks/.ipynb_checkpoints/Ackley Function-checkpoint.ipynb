# %% [markdown]
# # Ackley Function
#
# The Ackley function is a commonly used benchmark function in the field of optimization, particularly in evolutionary and genetic algorithms. It is a non-linear, multimodal function that presents a significant challenge for optimization algorithms due to its large search space and many local optima. The function is defined over a multi-dimensional domain, typically real numbers, and it is characterized by a nearly flat outer region, and a large hole at the center. The function is used to assess the performance of optimization algorithms - if an algorithm can find the global minimum of the Ackley function, it demonstrates that the algorithm is adept at escaping local optima. The global minimum for the Ackley function is usually at the origin (0,0) where the function value is also 0, for the common case of two dimensions. However, these values would extend to more zeros as the dimensions increase. The function poses a risk for optimization algorithms, particularly hill climbing algorithms, to be trapped in one of its many local minima. $a = 20$, $b = 0.2$ and $c = 2π$.
#
# The mathematical form is given by:
# $$f(\mathbf{x}) = -a \exp \left(-b \sqrt{\frac{1}{d} \sum_{i=1}^d x_i^2} \right) - \exp \left(\frac{1}{d} \sum_{i=1}^d \cos (c x_i) \right) + a + \exp(1)$$
#
# ## Input Domain
# The function is usually evaluated at $x_i \in [-32.768, 32.768]$, for all $i = 1, \ldots, d$, although it may also be restricted to a small domain.
#
# ## Global Minima
# The global minimum of the function is at $f(\textbf{x}^*) = 0$ at $x^* = (0, \ldots, 0)$.

# %%
import time

import matplotlib.pyplot as plt
import numpy as np
import torch

from pygranso.pygranso import pygranso
from pygranso.pygransoStruct import pygransoStruct

# %%
def objective(x, y):
    a = 20.0
    b = 0.2
    c = 2 * np.pi
    return (
        -a * np.exp(-b * np.sqrt(0.5 * (x**2 + y**2)))
        - np.exp(0.5 * (np.cos(c * x) + np.cos(c * y)))
        + a
        + np.e
    )

# %%
# Make sure the objecive function is correct
objective(0.0, 0.0)
# Out:
# 4.440892098500626e-16

# %%
# Plot the Ackley Function in 3D
r_min, r_max = -10, 10
x_axis = y_axis = np.arange(r_min, r_max, 0.05)
x, y = np.meshgrid(x_axis, y_axis)
f = objective(x, y)

figure = plt.figure()
axis = figure.add_subplot(111, projection="3d")
axis.plot_surface(x, y, f, cmap="jet", shade="false")

# Set the title
axis.set_title("Ackley Function Surface Plot")
# Out:
# Text(0.5, 0.92, 'Ackley Function Surface Plot')

# %%
# Let's also view the contours
figure = plt.figure(figsize=(4, 4))
plt.contour(x, y, f)

# %% [markdown]
# # `PyGranso` Solution
#
# The initial objective we've set for ourselves is to tackle the Ackley optimization problem using our proprietary software, PyGranso. The Ackley problem, known for its complexity and vast search space, offers a meaningful challenge to evaluate the efficiency and efficacy of our optimization algorithms. To begin with, we will examine the solution in a two-dimensional space, a common starting point for assessing the Ackley function. Once we have a satisfactory solution in two dimensions, we'll incrementally scale upward, expanding the problem's complexity by increasing the number of dimensions. This progressive approach will help us to thoroughly evaluate the robustness of PyGranso's solutions in higher-dimensional optimization scenarios.

# %% [markdown]
# ## Function Set-Up
#
# Encode teh optimization variables, and the objective and constraint functions.

# %%
# Setup the device
device = torch.device("cpu")

# Input variables
var_in = {"x1": [1], "x2": [1]}

def objective(x, y):
    a = 20.0
    b = 0.2
    c = 2 * np.pi
    return (
        -a * torch.exp(-b * torch.sqrt(0.5 * (x**2 + y**2)))
        - torch.exp(0.5 * (torch.cos(c * x) + torch.cos(c * y)))
        + a
        + torch.e
    )

# Create the combined function
def comb_fn(X_struct):
    x1 = X_struct.x1
    x2 = X_struct.x2

    # Objective function
    f = objective(x1, x2)

    # Inequality constraint
    ci = None

    # equality constraint
    ce = None

    return f, ci, ce

# %% [markdown]
# ## Main Algorithm

# %%
# Try many different random starts

for trial in range(10):
    # Setup a pygransoStruct for the algorithm
    # options
    opts = pygransoStruct()

    # With random variables between -32, 32
    x0 = (
        torch.rand(size=(2, 1), device=device, dtype=torch.double) * 64 - 32
    )

    opts.x0 = x0
    opts.torch_device = device

    # Run the main algorithm
    start = time.time()
    soln = pygranso(var_spec=var_in, combined_fn=comb_fn, user_opts=opts)
    end = time.time()

    print(f"Trial {trial + 1}")
    print(f"Starting point for problem = {x0}")
    print("\n")
    print("Total Wall Time: {}s".format(end - start))
    print(soln.final.x, soln.final.f)
    print("\n")
# Out:
# ╔═════ QP SOLVER NOTICE ════════════════════════════════════════════════════════════════════════╗
# ║  PyGRANSO requires a quadratic program (QP) solver that has a quadprog-compatible interface,  ║
# ║  the default is osqp. Users may provide their own wrapper for the QP solver.                  ║
# ║  To disable this notice, set opts.quadprog_info_msg = False                                   ║
# ╚═══════════════════════════════════════════════════════════════════════════════════════════════╝
# ══════════════════════════════════════════════════════════════════════════════════════════════╗
# PyGRANSO: A PyTorch-enabled port of GRANSO with auto-differentiation                          ║
# Version 1.2.0                                                                                 ║
# Licensed under the AGPLv3, Copyright (C) 2021-2022 Tim Mitchell and Buyun Liang               ║
# ══════════════════════════════════════════════════════════════════════════════════════════════╣
# Problem specifications:                                                                       ║
#  # of variables                     :   2                                                     ║
#  # of inequality constraints        :   0                                                     ║
#  # of equality constraints          :   0                                                     ║
# ═════╦════════════╦════════════════╦═════════════╦═══════════════════════╦════════════════════╣
#      ║ Penalty Fn ║                ║  Violation  ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║ Mu │ Value ║    Objective   ║ Ineq │  Eq  ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬════════════╬════════════════╬═════════════╬═══════════════════════╬════════════════════╣
#    0 ║  - │   -   ║  20.1263467526 ║   -  │   -  ║ -  │     1 │ 0.000000 ║     1 │ 4.620293   ║
#    1 ║  - │   -   ║  19.9325054453 ║   -  │   -  ║ QN │     6 │ 0.031250 ║     1 │ 2.342144   ║
#    2 ║  - │   -   ║  19.8794909400 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 0.004080   ║
#    3 ║  - │   -   ║  19.8791329621 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 1.25e-04   ║
#    4 ║  - │   -   ║  19.8791325897 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 6.18e-06   ║
#    5 ║  - │   -   ║  19.8791325889 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     2 │ 2.45e-06   ║
#    6 ║  - │   -   ║  19.8791325889 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     3 │ 1.48e-06   ║
#    7 ║  - │   -   ║  19.8791325889 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 2.00e-09   ║
# ═════╩════════════╩════════════════╩═════════════╩═══════════════════════╩════════════════════╣
# Optimization results:                                                                         ║
# F = final iterate, B = Best (to tolerance), MF = Most Feasible                                ║
# ═════╦════════════╦════════════════╦═════════════╦═══════════════════════╦════════════════════╣
#    F ║    │       ║  19.8791325889 ║   -  │   -  ║    │       │          ║       │            ║
#    B ║    │       ║  19.8791325889 ║   -  │   -  ║    │       │          ║       │            ║
# ═════╩════════════╩════════════════╩═════════════╩═══════════════════════╩════════════════════╣
# Iterations:              7                                                                    ║
# Function evaluations:    13                                                                   ║
# PyGRANSO termination code: 0 --- converged to stationarity tolerance.                         ║
# ══════════════════════════════════════════════════════════════════════════════════════════════╝
# Trial 1
# Starting point for problem = tensor([[ 23.9081],
#         [-27.0385]], dtype=torch.float64)
#
#
# Total Wall Time: 0.03284907341003418s
# tensor([[ 23.9998],
#         [-26.9998]], dtype=torch.float64) 19.879132588862237
#
#
#
#
# ╔═════ QP SOLVER NOTICE ════════════════════════════════════════════════════════════════════════╗
# ║  PyGRANSO requires a quadratic program (QP) solver that has a quadprog-compatible interface,  ║
# ║  the default is osqp. Users may provide their own wrapper for the QP solver.                  ║
# ║  To disable this notice, set opts.quadprog_info_msg = False                                   ║
# ╚═══════════════════════════════════════════════════════════════════════════════════════════════╝
# ══════════════════════════════════════════════════════════════════════════════════════════════╗
# PyGRANSO: A PyTorch-enabled port of GRANSO with auto-differentiation                          ║
# Version 1.2.0                                                                                 ║
# Licensed under the AGPLv3, Copyright (C) 2021-2022 Tim Mitchell and Buyun Liang               ║
# ══════════════════════════════════════════════════════════════════════════════════════════════╣
# Problem specifications:                                                                       ║
#  # of variables                     :   2                                                     ║
#  # of inequality constraints        :   0                                                     ║
#  # of equality constraints          :   0                                                     ║
# ═════╦════════════╦════════════════╦═════════════╦═══════════════════════╦════════════════════╣
#      ║ Penalty Fn ║                ║  Violation  ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║ Mu │ Value ║    Objective   ║ Ineq │  Eq  ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬════════════╬════════════════╬═════════════╬═══════════════════════╬════════════════════╣
#    0 ║  - │   -   ║  19.7175486162 ║   -  │   -  ║ -  │     1 │ 0.000000 ║     1 │ 1.749292   ║
#    1 ║  - │   -   ║  19.7007983759 ║   -  │   -  ║ QN │     6 │ 0.031250 ║     1 │ 1.148753   ║
#    2 ║  - │   -   ║  19.6883707393 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 1.10e-04   ║
#    3 ║  - │   -   ║  19.6883704248 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 8.25e-07   ║
#    4 ║  - │   -   ║  19.6883704248 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 1.78e-09   ║
# ═════╩════════════╩════════════════╩═════════════╩═══════════════════════╩════════════════════╣
# Optimization results:                                                                         ║
# F = final iterate, B = Best (to tolerance), MF = Most Feasible                                ║
# ═════╦════════════╦════════════════╦═════════════╦═══════════════════════╦════════════════════╣
#    F ║    │       ║  19.6883704248 ║   -  │   -  ║    │       │          ║       │            ║
#    B ║    │       ║  19.6883704248 ║   -  │   -  ║    │       │          ║       │            ║
# ═════╩════════════╩════════════════╩═════════════╩═══════════════════════╩════════════════════╣
# Iterations:              4                                                                    ║
# Function evaluations:    10                                                                   ║
# PyGRANSO termination code: 0 --- converged to stationarity tolerance.                         ║
# ══════════════════════════════════════════════════════════════════════════════════════════════╝
# Trial 2
# Starting point for problem = tensor([[ -5.0297],
#         [-29.0135]], dtype=torch.float64)
#
#
# Total Wall Time: 0.017491817474365234s
# tensor([[ -4.9999],
#         [-28.9992]], dtype=torch.float64) 19.688370424772106
#
#
#
#
# ╔═════ QP SOLVER NOTICE ════════════════════════════════════════════════════════════════════════╗
# ║  PyGRANSO requires a quadratic program (QP) solver that has a quadprog-compatible interface,  ║
# ║  the default is osqp. Users may provide their own wrapper for the QP solver.                  ║
# ║  To disable this notice, set opts.quadprog_info_msg = False                                   ║
# ╚═══════════════════════════════════════════════════════════════════════════════════════════════╝
# ══════════════════════════════════════════════════════════════════════════════════════════════╗
# PyGRANSO: A PyTorch-enabled port of GRANSO with auto-differentiation                          ║
# Version 1.2.0                                                                                 ║
# Licensed under the AGPLv3, Copyright (C) 2021-2022 Tim Mitchell and Buyun Liang               ║
# ══════════════════════════════════════════════════════════════════════════════════════════════╣
# Problem specifications:                                                                       ║
#  # of variables                     :   2                                                     ║
#  # of inequality constraints        :   0                                                     ║
#  # of equality constraints          :   0                                                     ║
# ═════╦════════════╦════════════════╦═════════════╦═══════════════════════╦════════════════════╣
#      ║ Penalty Fn ║                ║  Violation  ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║ Mu │ Value ║    Objective   ║ Ineq │  Eq  ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬════════════╬════════════════╬═════════════╬═══════════════════════╬════════════════════╣
#    0 ║  - │   -   ║  20.6465736492 ║   -  │   -  ║ -  │     1 │ 0.000000 ║     1 │ 5.669089   ║
#    1 ║  - │   -   ║  20.6100186848 ║   -  │   -  ║ QN │     3 │ 0.250000 ║     1 │ 5.715037   ║
#    2 ║  - │   -   ║  20.2907789663 ║   -  │   -  ║ QN │     2 │ 0.500000 ║     1 │ 0.700268   ║
#    3 ║  - │   -   ║  19.8029508688 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 0.053822   ║
#    4 ║  - │   -   ║  19.7965667905 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 0.132613   ║
#    5 ║  - │   -   ║  19.7943777436 ║   -  │   -  ║ QN │     2 │ 0.500000 ║     1 │ 0.088586   ║
#    6 ║  - │   -   ║  19.7845838302 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 0.007035   ║
#    7 ║  - │   -   ║  19.7838840154 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 4.56e-04   ║
#    8 ║  - │   -   ║  19.7838797022 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 2.67e-05   ║
#    9 ║  - │   -   ║  19.7838796858 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     2 │ 4.16e-06   ║
#   10 ║  - │   -   ║  19.7838796858 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     3 │ 1.82e-06   ║
# ═════╩════════════╩════════════════╩═════════════╩═══════════════════════╩════════════════════╣
# Optimization results:                                                                         ║
# F = final iterate, B = Best (to tolerance), MF = Most Feasible                                ║
# ═════╦════════════╦════════════════╦═════════════╦═══════════════════════╦════════════════════╣
#    F ║    │       ║  19.7838796858 ║   -  │   -  ║    │       │          ║       │            ║
#    B ║    │       ║  19.7838796858 ║   -  │   -  ║    │       │          ║       │            ║
# ═════╩════════════╩════════════════╩═════════════╩═══════════════════════╩════════════════════╣
# Iterations:              10                                                                   ║
# Function evaluations:    24                                                                   ║
# PyGRANSO termination code: 6 --- line search bracketed a minimizer but failed to satisfy      ║
# Wolfe conditions.  This may be an indication that approximate stationarity has been attained. ║
# ══════════════════════════════════════════════════════════════════════════════════════════════╝
# Trial 3
# Starting point for problem = tensor([[-31.9987],
#         [ -2.2117]], dtype=torch.float64)
#
#
# Total Wall Time: 0.036940813064575195s
# tensor([[-31.9994],
#         [ -1.0000]], dtype=torch.float64) 19.783879685819215
#
#
#
#
# ╔═════ QP SOLVER NOTICE ════════════════════════════════════════════════════════════════════════╗
# ║  PyGRANSO requires a quadratic program (QP) solver that has a quadprog-compatible interface,  ║
# ║  the default is osqp. Users may provide their own wrapper for the QP solver.                  ║
# ║  To disable this notice, set opts.quadprog_info_msg = False                                   ║
# ╚═══════════════════════════════════════════════════════════════════════════════════════════════╝
# ══════════════════════════════════════════════════════════════════════════════════════════════╗
# PyGRANSO: A PyTorch-enabled port of GRANSO with auto-differentiation                          ║
# Version 1.2.0                                                                                 ║
# Licensed under the AGPLv3, Copyright (C) 2021-2022 Tim Mitchell and Buyun Liang               ║
# ══════════════════════════════════════════════════════════════════════════════════════════════╣
# Problem specifications:                                                                       ║
#  # of variables                     :   2                                                     ║
#  # of inequality constraints        :   0                                                     ║
#  # of equality constraints          :   0                                                     ║
# ═════╦════════════╦════════════════╦═════════════╦═══════════════════════╦════════════════════╣
#      ║ Penalty Fn ║                ║  Violation  ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║ Mu │ Value ║    Objective   ║ Ineq │  Eq  ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬════════════╬════════════════╬═════════════╬═══════════════════════╬════════════════════╣
#    0 ║  - │   -   ║  20.3705792834 ║   -  │   -  ║ -  │     1 │ 0.000000 ║     1 │ 1.728742   ║
#    1 ║  - │   -   ║  20.1918556991 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 2.634004   ║
#    2 ║  - │   -   ║  19.0852362017 ║   -  │   -  ║ QN │     2 │ 0.500000 ║     1 │ 2.195619   ║
#    3 ║  - │   -   ║  18.7923997824 ║   -  │   -  ║ QN │     2 │ 0.500000 ║     1 │ 2.394669   ║
#    4 ║  - │   -   ║  18.7426160952 ║   -  │   -  ║ QN │     4 │ 0.125000 ║     1 │ 1.147155   ║
#    5 ║  - │   -   ║  18.5222246984 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 0.024416   ║
#    6 ║  - │   -   ║  18.5143121781 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 0.003330   ║
#    7 ║  - │   -   ║  18.5141186199 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 3.04e-04   ║
#    8 ║  - │   -   ║  18.5141169456 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 3.73e-05   ║
#    9 ║  - │   -   ║  18.5141169176 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     2 │ 6.00e-07   ║
#   10 ║  - │   -   ║  18.5141169176 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     3 │ 4.76e-07   ║
#   11 ║  - │   -   ║  18.5141169176 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 3.61e-09   ║
# ═════╩════════════╩════════════════╩═════════════╩═══════════════════════╩════════════════════╣
# Optimization results:                                                                         ║
# F = final iterate, B = Best (to tolerance), MF = Most Feasible                                ║
# ═════╦════════════╦════════════════╦═════════════╦═══════════════════════╦════════════════════╣
#    F ║    │       ║  18.5141169176 ║   -  │   -  ║    │       │          ║       │            ║
#    B ║    │       ║  18.5141169176 ║   -  │   -  ║    │       │          ║       │            ║
# ═════╩════════════╩════════════════╩═════════════╩═══════════════════════╩════════════════════╣
# Iterations:              11                                                                   ║
# Function evaluations:    17                                                                   ║
# PyGRANSO termination code: 0 --- converged to stationarity tolerance.                         ║
# ══════════════════════════════════════════════════════════════════════════════════════════════╝
# Trial 4
# Starting point for problem = tensor([[ 12.5590],
#         [-11.7289]], dtype=torch.float64)
#
#
# Total Wall Time: 0.028934001922607422s
# tensor([[ 12.9972],
#         [-12.9972]], dtype=torch.float64) 18.514116917626552
#
#
#
#
# ╔═════ QP SOLVER NOTICE ════════════════════════════════════════════════════════════════════════╗
# ║  PyGRANSO requires a quadratic program (QP) solver that has a quadprog-compatible interface,  ║
# ║  the default is osqp. Users may provide their own wrapper for the QP solver.                  ║
# ║  To disable this notice, set opts.quadprog_info_msg = False                                   ║
# ╚═══════════════════════════════════════════════════════════════════════════════════════════════╝
# ══════════════════════════════════════════════════════════════════════════════════════════════╗
# PyGRANSO: A PyTorch-enabled port of GRANSO with auto-differentiation                          ║
# Version 1.2.0                                                                                 ║
# Licensed under the AGPLv3, Copyright (C) 2021-2022 Tim Mitchell and Buyun Liang               ║
# ══════════════════════════════════════════════════════════════════════════════════════════════╣
# Problem specifications:                                                                       ║
#  # of variables                     :   2                                                     ║
#  # of inequality constraints        :   0                                                     ║
#  # of equality constraints          :   0                                                     ║
# ═════╦════════════╦════════════════╦═════════════╦═══════════════════════╦════════════════════╣
#      ║ Penalty Fn ║                ║  Violation  ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║ Mu │ Value ║    Objective   ║ Ineq │  Eq  ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬════════════╬════════════════╬═════════════╬═══════════════════════╬════════════════════╣
#    0 ║  - │   -   ║  18.4635337688 ║   -  │   -  ║ -  │     1 │ 0.000000 ║     1 │ 5.284617   ║
#    1 ║  - │   -   ║  14.7349273845 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 4.829507   ║
#    2 ║  - │   -   ║  14.5943455435 ║   -  │   -  ║ QN │     7 │ 0.015625 ║     1 │ 4.142844   ║
#    3 ║  - │   -   ║  14.4559239644 ║   -  │   -  ║ QN │     5 │ 0.062500 ║     1 │ 0.150261   ║
#    4 ║  - │   -   ║  14.4377038952 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 0.006674   ║
#    5 ║  - │   -   ║  14.4369528933 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 4.15e-04   ║
#    6 ║  - │   -   ║  14.4369497193 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 5.73e-05   ║
#    7 ║  - │   -   ║  14.4369496549 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     2 │ 2.41e-05   ║
#    8 ║  - │   -   ║  14.4369496549 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     3 │ 3.50e-07   ║
#    9 ║  - │   -   ║  14.4369496549 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 2.94e-09   ║
# ═════╩════════════╩════════════════╩═════════════╩═══════════════════════╩════════════════════╣
# Optimization results:                                                                         ║
# F = final iterate, B = Best (to tolerance), MF = Most Feasible                                ║
# ═════╦════════════╦════════════════╦═════════════╦═══════════════════════╦════════════════════╣
#    F ║    │       ║  14.4369496549 ║   -  │   -  ║    │       │          ║       │            ║
#    B ║    │       ║  14.4369496549 ║   -  │   -  ║    │       │          ║       │            ║
# ═════╩════════════╩════════════════╩═════════════╩═══════════════════════╩════════════════════╣
# Iterations:              9                                                                    ║
# Function evaluations:    20                                                                   ║
# PyGRANSO termination code: 0 --- converged to stationarity tolerance.                         ║
# ══════════════════════════════════════════════════════════════════════════════════════════════╝
# Trial 5
# Starting point for problem = tensor([[ 2.1330],
#         [13.2808]], dtype=torch.float64)
#
#
# Total Wall Time: 0.026730060577392578s
# tensor([[-0.9984],
#         [ 8.9854]], dtype=torch.float64) 14.436949654920966
#
#
#
#
# ╔═════ QP SOLVER NOTICE ════════════════════════════════════════════════════════════════════════╗
# ║  PyGRANSO requires a quadratic program (QP) solver that has a quadprog-compatible interface,  ║
# ║  the default is osqp. Users may provide their own wrapper for the QP solver.                  ║
# ║  To disable this notice, set opts.quadprog_info_msg = False                                   ║
# ╚═══════════════════════════════════════════════════════════════════════════════════════════════╝
# ══════════════════════════════════════════════════════════════════════════════════════════════╗
# PyGRANSO: A PyTorch-enabled port of GRANSO with auto-differentiation                          ║
# Version 1.2.0                                                                                 ║
# Licensed under the AGPLv3, Copyright (C) 2021-2022 Tim Mitchell and Buyun Liang               ║
# ══════════════════════════════════════════════════════════════════════════════════════════════╣
# Problem specifications:                                                                       ║
#  # of variables                     :   2                                                     ║
#  # of inequality constraints        :   0                                                     ║
#  # of equality constraints          :   0                                                     ║
# ═════╦════════════╦════════════════╦═════════════╦═══════════════════════╦════════════════════╣
#      ║ Penalty Fn ║                ║  Violation  ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║ Mu │ Value ║    Objective   ║ Ineq │  Eq  ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬════════════╬════════════════╬═════════════╬═══════════════════════╬════════════════════╣
#    0 ║  - │   -   ║  21.7515812443 ║   -  │   -  ║ -  │     1 │ 0.000000 ║     1 │ 2.173685   ║
#    1 ║  - │   -   ║  21.6066403724 ║   -  │   -  ║ QN │     2 │ 2.000000 ║     1 │ 0.904047   ║
#    2 ║  - │   -   ║  21.5940985494 ║   -  │   -  ║ QN │     5 │ 0.062500 ║     1 │ 0.827403   ║
#    3 ║  - │   -   ║  21.5532242351 ║   -  │   -  ║ QN │     3 │ 4.000000 ║     1 │ 3.017950   ║
#    4 ║  - │   -   ║  21.4383632226 ║   -  │   -  ║ QN │     2 │ 0.500000 ║     1 │ 34.80680   ║
#    5 ║  - │   -   ║  20.4422556422 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 29.43777   ║
#    6 ║  - │   -   ║  20.2750028621 ║   -  │   -  ║ QN │     6 │ 0.031250 ║     1 │ 2.560310   ║
#    7 ║  - │   -   ║  20.0203798320 ║   -  │   -  ║ QN │     2 │ 2.000000 ║     1 │ 0.069021   ║
#    8 ║  - │   -   ║  19.9069599837 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 0.015811   ║
#    9 ║  - │   -   ║  19.8951689896 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 0.002618   ║
#   10 ║  - │   -   ║  19.8950226489 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 6.05e-05   ║
#   11 ║  - │   -   ║  19.8950225905 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     2 │ 3.96e-06   ║
#   12 ║  - │   -   ║  19.8950225864 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     3 │ 2.20e-06   ║
#   13 ║  - │   -   ║  19.8950225864 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     4 │ 1.55e-06   ║
# ═════╩════════════╩════════════════╩═════════════╩═══════════════════════╩════════════════════╣
# Optimization results:                                                                         ║
# F = final iterate, B = Best (to tolerance), MF = Most Feasible                                ║
# ═════╦════════════╦════════════════╦═════════════╦═══════════════════════╦════════════════════╣
#    F ║    │       ║  19.8950225864 ║   -  │   -  ║    │       │          ║       │            ║
#    B ║    │       ║  19.8950225864 ║   -  │   -  ║    │       │          ║       │            ║
# ═════╩════════════╩════════════════╩═════════════╩═══════════════════════╩════════════════════╣
# Iterations:              13                                                                   ║
# Function evaluations:    36                                                                   ║
# PyGRANSO termination code: 6 --- line search bracketed a minimizer but failed to satisfy      ║
# Wolfe conditions.  This may be an indication that approximate stationarity has been attained. ║
# ══════════════════════════════════════════════════════════════════════════════════════════════╝
# Trial 6
# Starting point for problem = tensor([[  6.4668],
#         [-30.8084]], dtype=torch.float64)
#
#
# Total Wall Time: 0.04198908805847168s
# tensor([[  3.0000],
#         [-36.9997]], dtype=torch.float64) 19.895022586446142
#
#
#
#
# ╔═════ QP SOLVER NOTICE ════════════════════════════════════════════════════════════════════════╗
# ║  PyGRANSO requires a quadratic program (QP) solver that has a quadprog-compatible interface,  ║
# ║  the default is osqp. Users may provide their own wrapper for the QP solver.                  ║
# ║  To disable this notice, set opts.quadprog_info_msg = False                                   ║
# ╚═══════════════════════════════════════════════════════════════════════════════════════════════╝
# ══════════════════════════════════════════════════════════════════════════════════════════════╗
# PyGRANSO: A PyTorch-enabled port of GRANSO with auto-differentiation                          ║
# Version 1.2.0                                                                                 ║
# Licensed under the AGPLv3, Copyright (C) 2021-2022 Tim Mitchell and Buyun Liang               ║
# ══════════════════════════════════════════════════════════════════════════════════════════════╣
# Problem specifications:                                                                       ║
#  # of variables                     :   2                                                     ║
#  # of inequality constraints        :   0                                                     ║
#  # of equality constraints          :   0                                                     ║
# ═════╦════════════╦════════════════╦═════════════╦═══════════════════════╦════════════════════╣
#      ║ Penalty Fn ║                ║  Violation  ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║ Mu │ Value ║    Objective   ║ Ineq │  Eq  ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬════════════╬════════════════╬═════════════╬═══════════════════════╬════════════════════╣
#    0 ║  - │   -   ║  20.7875081394 ║   -  │   -  ║ -  │     1 │ 0.000000 ║     1 │ 5.261848   ║
#    1 ║  - │   -   ║  19.8646394917 ║   -  │   -  ║ QN │     2 │ 0.500000 ║     1 │ 5.390938   ║
#    2 ║  - │   -   ║  19.4617427461 ║   -  │   -  ║ QN │     4 │ 0.125000 ║     1 │ 0.541319   ║
#    3 ║  - │   -   ║  19.4511108190 ║   -  │   -  ║ QN │     4 │ 0.125000 ║     1 │ 0.257079   ║
#    4 ║  - │   -   ║  19.4335973770 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 0.011886   ║
#    5 ║  - │   -   ║  19.4316785304 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 4.39e-04   ║
#    6 ║  - │   -   ║  19.4316742912 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 2.75e-05   ║
#    7 ║  - │   -   ║  19.4316742738 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     2 │ 2.43e-06   ║
#    8 ║  - │   -   ║  19.4316742738 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     3 │ 5.89e-07   ║
# ═════╩════════════╩════════════════╩═════════════╩═══════════════════════╩════════════════════╣
# Optimization results:                                                                         ║
# F = final iterate, B = Best (to tolerance), MF = Most Feasible                                ║
# ═════╦════════════╦════════════════╦═════════════╦═══════════════════════╦════════════════════╣
#    F ║    │       ║  19.4316742738 ║   -  │   -  ║    │       │          ║       │            ║
#    B ║    │       ║  19.4316742738 ║   -  │   -  ║    │       │          ║       │            ║
# ═════╩════════════╩════════════════╩═════════════╩═══════════════════════╩════════════════════╣
# Iterations:              8                                                                    ║
# Function evaluations:    25                                                                   ║
# PyGRANSO termination code: 6 --- line search bracketed a minimizer but failed to satisfy      ║
# Wolfe conditions.  This may be an indication that approximate stationarity has been attained. ║
# ══════════════════════════════════════════════════════════════════════════════════════════════╝
# Trial 7
# Starting point for problem = tensor([[-1.9246],
#         [27.2602]], dtype=torch.float64)
#
#
# Total Wall Time: 0.030261993408203125s
# tensor([[-2.9998],
#         [24.9985]], dtype=torch.float64) 19.43167427382149
#
#
#
#
# ╔═════ QP SOLVER NOTICE ════════════════════════════════════════════════════════════════════════╗
# ║  PyGRANSO requires a quadratic program (QP) solver that has a quadprog-compatible interface,  ║
# ║  the default is osqp. Users may provide their own wrapper for the QP solver.                  ║
# ║  To disable this notice, set opts.quadprog_info_msg = False                                   ║
# ╚═══════════════════════════════════════════════════════════════════════════════════════════════╝
# ══════════════════════════════════════════════════════════════════════════════════════════════╗
# PyGRANSO: A PyTorch-enabled port of GRANSO with auto-differentiation                          ║
# Version 1.2.0                                                                                 ║
# Licensed under the AGPLv3, Copyright (C) 2021-2022 Tim Mitchell and Buyun Liang               ║
# ══════════════════════════════════════════════════════════════════════════════════════════════╣
# Problem specifications:                                                                       ║
#  # of variables                     :   2                                                     ║
#  # of inequality constraints        :   0                                                     ║
#  # of equality constraints          :   0                                                     ║
# ═════╦════════════╦════════════════╦═════════════╦═══════════════════════╦════════════════════╣
#      ║ Penalty Fn ║                ║  Violation  ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║ Mu │ Value ║    Objective   ║ Ineq │  Eq  ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬════════════╬════════════════╬═════════════╬═══════════════════════╬════════════════════╣
#    0 ║  - │   -   ║  19.7174528673 ║   -  │   -  ║ -  │     1 │ 0.000000 ║     1 │ 4.049654   ║
#    1 ║  - │   -   ║  19.5904016300 ║   -  │   -  ║ QN │     6 │ 0.031250 ║     1 │ 2.266452   ║
#    2 ║  - │   -   ║  19.5406843214 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 0.002199   ║
#    3 ║  - │   -   ║  19.5405727886 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 6.18e-05   ║
#    4 ║  - │   -   ║  19.5405726936 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 1.45e-06   ║
#    5 ║  - │   -   ║  19.5405726936 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     2 │ 6.74e-07   ║
#    6 ║  - │   -   ║  19.5405726936 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 9.11e-09   ║
# ═════╩════════════╩════════════════╩═════════════╩═══════════════════════╩════════════════════╣
# Optimization results:                                                                         ║
# F = final iterate, B = Best (to tolerance), MF = Most Feasible                                ║
# ═════╦════════════╦════════════════╦═════════════╦═══════════════════════╦════════════════════╣
#    F ║    │       ║  19.5405726936 ║   -  │   -  ║    │       │          ║       │            ║
#    B ║    │       ║  19.5405726936 ║   -  │   -  ║    │       │          ║       │            ║
# ═════╩════════════╩════════════════╩═════════════╩═══════════════════════╩════════════════════╣
# Iterations:              6                                                                    ║
# Function evaluations:    12                                                                   ║
# PyGRANSO termination code: 0 --- converged to stationarity tolerance.                         ║
# ══════════════════════════════════════════════════════════════════════════════════════════════╝
# Trial 8
# Starting point for problem = tensor([[-26.0367],
#         [ -5.9257]], dtype=torch.float64)
#
#
# Total Wall Time: 0.03545093536376953s
# tensor([[-25.9988],
#         [ -5.9997]], dtype=torch.float64) 19.54057269358265
#
#
#
#
# ╔═════ QP SOLVER NOTICE ════════════════════════════════════════════════════════════════════════╗
# ║  PyGRANSO requires a quadratic program (QP) solver that has a quadprog-compatible interface,  ║
# ║  the default is osqp. Users may provide their own wrapper for the QP solver.                  ║
# ║  To disable this notice, set opts.quadprog_info_msg = False                                   ║
# ╚═══════════════════════════════════════════════════════════════════════════════════════════════╝
# ══════════════════════════════════════════════════════════════════════════════════════════════╗
# PyGRANSO: A PyTorch-enabled port of GRANSO with auto-differentiation                          ║
# Version 1.2.0                                                                                 ║
# Licensed under the AGPLv3, Copyright (C) 2021-2022 Tim Mitchell and Buyun Liang               ║
# ══════════════════════════════════════════════════════════════════════════════════════════════╣
# Problem specifications:                                                                       ║
#  # of variables                     :   2                                                     ║
#  # of inequality constraints        :   0                                                     ║
#  # of equality constraints          :   0                                                     ║
# ═════╦════════════╦════════════════╦═════════════╦═══════════════════════╦════════════════════╣
#      ║ Penalty Fn ║                ║  Violation  ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║ Mu │ Value ║    Objective   ║ Ineq │  Eq  ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬════════════╬════════════════╬═════════════╬═══════════════════════╬════════════════════╣
#    0 ║  - │   -   ║  18.9014285656 ║   -  │   -  ║ -  │     1 │ 0.000000 ║     1 │ 3.866478   ║
#    1 ║  - │   -   ║  18.1428748684 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 5.594331   ║
#    2 ║  - │   -   ║  16.5807420191 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 2.532870   ║
#    3 ║  - │   -   ║  15.6760551346 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 7.058625   ║
#    4 ║  - │   -   ║  15.4819665502 ║   -  │   -  ║ QN │     3 │ 0.250000 ║     1 │ 0.076260   ║
#    5 ║  - │   -   ║  14.8686443851 ║   -  │   -  ║ QN │     8 │ 128.0000 ║     1 │ 11.08777   ║
#    6 ║  - │   -   ║  12.7376897560 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 4.134403   ║
#    7 ║  - │   -   ║  12.3194202759 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 3.416292   ║
#    8 ║  - │   -   ║  12.1356851486 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 21.83037   ║
#    9 ║  - │   -   ║  11.5214008529 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 7.146429   ║
#   10 ║  - │   -   ║  10.2107903660 ║   -  │   -  ║ QN │     2 │ 2.000000 ║     1 │ 1.583415   ║
#   11 ║  - │   -   ║  9.46095708343 ║   -  │   -  ║ QN │     7 │ 3.125000 ║     1 │ 9.195056   ║
#   12 ║  - │   -   ║  6.19340938220 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 0.517587   ║
#   13 ║  - │   -   ║  4.60806840710 ║   -  │   -  ║ QN │     2 │ 2.000000 ║     1 │ 0.165017   ║
#   14 ║  - │   -   ║  4.38859876665 ║   -  │   -  ║ QN │     4 │ 8.000000 ║     1 │ 2.047322   ║
#   15 ║  - │   -   ║  4.34425387248 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 2.987496   ║
#   16 ║  - │   -   ║  3.14836121176 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 1.518264   ║
#   17 ║  - │   -   ║  3.13029194251 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 2.833286   ║
#   18 ║  - │   -   ║  2.75785450401 ║   -  │   -  ║ QN │     4 │ 0.125000 ║     1 │ 1.532937   ║
#   19 ║  - │   -   ║  0.17971786263 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 0.267109   ║
# ═════╬════════════╬════════════════╬═════════════╬═══════════════════════╬════════════════════╣
#      ║ Penalty Fn ║                ║  Violation  ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║ Mu │ Value ║    Objective   ║ Ineq │  Eq  ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬════════════╬════════════════╬═════════════╬═══════════════════════╬════════════════════╣
#   20 ║  - │   -   ║  0.11883385870 ║   -  │   -  ║ QN │     4 │ 0.125000 ║     1 │ 0.508449   ║
#   21 ║  - │   -   ║  0.07932355478 ║   -  │   -  ║ QN │     3 │ 0.250000 ║     1 │ 0.163826   ║
#   22 ║  - │   -   ║  0.01690682484 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 0.026158   ║
#   23 ║  - │   -   ║  0.00546966849 ║   -  │   -  ║ QN │     2 │ 0.500000 ║     1 │ 0.024444   ║
#   24 ║  - │   -   ║  0.00393300437 ║   -  │   -  ║ QN │     4 │ 0.125000 ║     1 │ 0.009973   ║
#   25 ║  - │   -   ║  0.00364602557 ║   -  │   -  ║ QN │     2 │ 0.500000 ║     1 │ 0.005506   ║
#   26 ║  - │   -   ║  4.3590607e-04 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 0.001633   ║
#   27 ║  - │   -   ║  2.4779513e-04 ║   -  │   -  ║ QN │     3 │ 0.250000 ║     1 │ 0.001976   ║
#   28 ║  - │   -   ║  2.3492741e-04 ║   -  │   -  ║ QN │     4 │ 0.125000 ║     1 │ 0.001051   ║
#   29 ║  - │   -   ║  1.1976636e-04 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 1.40e-04   ║
#   30 ║  - │   -   ║  5.8992838e-05 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     2 │ 1.44e-05   ║
#   31 ║  - │   -   ║  4.1039463e-05 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     3 │ 4.45e-14   ║
# ═════╩════════════╩════════════════╩═════════════╩═══════════════════════╩════════════════════╣
# Optimization results:                                                                         ║
# F = final iterate, B = Best (to tolerance), MF = Most Feasible                                ║
# ═════╦════════════╦════════════════╦═════════════╦═══════════════════════╦════════════════════╣
#    F ║    │       ║  4.1039463e-05 ║   -  │   -  ║    │       │          ║       │            ║
#    B ║    │       ║  4.1039463e-05 ║   -  │   -  ║    │       │          ║       │            ║
# ═════╩════════════╩════════════════╩═════════════╩═══════════════════════╩════════════════════╣
# Iterations:              31                                                                   ║
# Function evaluations:    70                                                                   ║
# PyGRANSO termination code: 0 --- converged to stationarity tolerance.                         ║
# ══════════════════════════════════════════════════════════════════════════════════════════════╝
# Trial 9
# Starting point for problem = tensor([[ -4.6552],
#         [-13.1425]], dtype=torch.float64)
#
#
# Total Wall Time: 0.08527994155883789s
# tensor([[-1.1153e-05],
#         [-9.2786e-06]], dtype=torch.float64) 4.1039463053227365e-05
#
#
#
#
# ╔═════ QP SOLVER NOTICE ════════════════════════════════════════════════════════════════════════╗
# ║  PyGRANSO requires a quadratic program (QP) solver that has a quadprog-compatible interface,  ║
# ║  the default is osqp. Users may provide their own wrapper for the QP solver.                  ║
# ║  To disable this notice, set opts.quadprog_info_msg = False                                   ║
# ╚═══════════════════════════════════════════════════════════════════════════════════════════════╝
# ══════════════════════════════════════════════════════════════════════════════════════════════╗
# PyGRANSO: A PyTorch-enabled port of GRANSO with auto-differentiation                          ║
# Version 1.2.0                                                                                 ║
# Licensed under the AGPLv3, Copyright (C) 2021-2022 Tim Mitchell and Buyun Liang               ║
# ══════════════════════════════════════════════════════════════════════════════════════════════╣
# Problem specifications:                                                                       ║
#  # of variables                     :   2                                                     ║
#  # of inequality constraints        :   0                                                     ║
#  # of equality constraints          :   0                                                     ║
# ═════╦════════════╦════════════════╦═════════════╦═══════════════════════╦════════════════════╣
#      ║ Penalty Fn ║                ║  Violation  ║ <--- Line Search ---> ║ <- Stationarity -> ║
# Iter ║ Mu │ Value ║    Objective   ║ Ineq │  Eq  ║ SD │ Evals │     t    ║ Grads │    Value   ║
# ═════╬════════════╬════════════════╬═════════════╬═══════════════════════╬════════════════════╣
#    0 ║  - │   -   ║  20.8274116244 ║   -  │   -  ║ -  │     1 │ 0.000000 ║     1 │ 2.228784   ║
#    1 ║  - │   -   ║  19.1301786792 ║   -  │   -  ║ QN │     2 │ 2.000000 ║     1 │ 3.652891   ║
#    2 ║  - │   -   ║  18.7572267768 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 2.550271   ║
#    3 ║  - │   -   ║  18.4386908998 ║   -  │   -  ║ QN │     6 │ 0.031250 ║     1 │ 7.447891   ║
#    4 ║  - │   -   ║  18.0097123513 ║   -  │   -  ║ QN │     4 │ 0.125000 ║     1 │ 5.157152   ║
#    5 ║  - │   -   ║  17.3881311892 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 0.167627   ║
#    6 ║  - │   -   ║  17.2616285764 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 0.076313   ║
#    7 ║  - │   -   ║  17.2538749665 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 0.066326   ║
#    8 ║  - │   -   ║  17.2384796405 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 0.012309   ║
#    9 ║  - │   -   ║  17.2369993883 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 0.002388   ║
#   10 ║  - │   -   ║  17.2369132022 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 1.35e-04   ║
#   11 ║  - │   -   ║  17.2369128147 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     1 │ 7.49e-06   ║
#   12 ║  - │   -   ║  17.2369128134 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     2 │ 3.06e-06   ║
#   13 ║  - │   -   ║  17.2369128134 ║   -  │   -  ║ QN │     1 │ 1.000000 ║     3 │ 2.03e-06   ║
# ═════╩════════════╩════════════════╩═════════════╩═══════════════════════╩════════════════════╣
# Optimization results:                                                                         ║
# F = final iterate, B = Best (to tolerance), MF = Most Feasible                                ║
# ═════╦════════════╦════════════════╦═════════════╦═══════════════════════╦════════════════════╣
#    F ║    │       ║  17.2369128134 ║   -  │   -  ║    │       │          ║       │            ║
#    B ║    │       ║  17.2369128134 ║   -  │   -  ║    │       │          ║       │            ║
# ═════╩════════════╩════════════════╩═════════════╩═══════════════════════╩════════════════════╣
# Iterations:              13                                                                   ║
# Function evaluations:    31                                                                   ║
# PyGRANSO termination code: 6 --- line search bracketed a minimizer but failed to satisfy      ║
# Wolfe conditions.  This may be an indication that approximate stationarity has been attained. ║
# ══════════════════════════════════════════════════════════════════════════════════════════════╝
# Trial 10
# Starting point for problem = tensor([[ -3.4569],
#         [-19.2431]], dtype=torch.float64)
#
#
# Total Wall Time: 0.04169297218322754s
# tensor([[-9.3721e-11],
#         [-1.3993e+01]], dtype=torch.float64) 17.23691281340265

# %% [markdown]
# # First Observations 👀
#
# Our preliminary findings indicate that the Ackley function poses a considerable challenge for our proprietary software, PyGranso, especially when it comes to finding an easy solution from arbitrary starting points. Given the complex nature of the Ackley function with its multitude of local optima, it's not entirely surprising that PyGranso struggles to find a quick and efficient solution. However, this realization provides an impetus for further exploration and fine-tuning of our methods. In the forthcoming stages of our research, we intend to investigate more deeply and also introduce alternative optimization solvers into our toolkit. One promising candidate is IPOPT, a powerful open-source optimizer that has demonstrated efficacy in solving a wide range of complex optimization problems. By utilizing a diverse array of solvers, we aim to enhance our ability to handle complex optimization challenges such as the Ackley function.
